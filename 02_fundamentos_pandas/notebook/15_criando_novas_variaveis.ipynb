# %% [markdown]
# # Relatório de Análise VI

# %% [markdown]
# ## Criando Novas Variáveis

# %%
import pandas as pd

# %%
dados = pd.read_csv('../dados/aluguel_residencial_notnull.csv', sep=';')
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU
# 0   1700.0       500.0  60.0
# 1   7000.0         0.0   0.0
# 2    800.0       390.0  20.0
# 3    800.0       230.0   0.0
# ...

# %% [markdown]
# ## Criando uma Variável (coluna)

# %% [markdown]
# ### Somando valores de outras colunas

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor Bruto
# 0   1700.0       500.0  60.0       2260.0
# 1   7000.0         0.0   0.0       7000.0
# ...

# %% [markdown]
# ### Usando Divisão

# %%
dados['Valor m2'] = dados['Valor'] / dados['Area']
dados.head(10).sort_index(axis=1, ascending=False)
# para melhor visualização o cabeçalho da coluna foi organizado de trás para frente
# para não cortar a coluna quando exportar o arquivo para pdf
# utilizou-se então a função sort_index, com os parâmetros:
# axis=1 => para organizar as colunas
# ascending=False => para organizar de maneira decrescente
# Out:
#     Valor m2  Valor Bruto    Valor  Vagas                Tipo  Suites  \
# 0  42.500000       2260.0   1700.0      0           Quitinete       0
# 1  70.000000       7000.0   7000.0      0                Casa       1
# 2  53.333333       1210.0    800.0      0         Apartamento       0
# 3  16.666667       1030.0    800.0      0         Apartamento       0
# 4  26.000000       1618.0   1300.0      0         Apartamento       0
# 5  29.333333      22000.0  22000.0      4  Casa de Condomínio       5
# 6  15.384615       1000.0   1000.0      2  Casa de Condomínio       0
# 7  21.428571       2216.0   1500.0      1         Apartamento       0
# 8  16.666667       1969.0   1500.0      1         Apartamento       1
# 9  50.000000       2611.0   2000.0      0         Apartamento       1
#
#    Quartos  IPTU  Condominio               Bairro  Area
# 0        1  60.0       500.0           Copacabana    40
# 1        2   0.0         0.0      Jardim Botânico   100
# ...

# %% [markdown]
# ### Arrendondando as casas decimais

# %%
dados['Valor m2'] = dados['Valor m2'].round(2)
dados.head(10).sort_index(axis=1, ascending=False)
# também é possível arredondar diretamente, colocando tudo entre parênteses
# dados['Valor m2'] = (dados['Valor'] / dados['Area']).round(2)
# Out:
#    Valor m2  Valor Bruto    Valor  Vagas                Tipo  Suites  Quartos  \
# 0     42.50       2260.0   1700.0      0           Quitinete       0        1
# 1     70.00       7000.0   7000.0      0                Casa       1        2
# 2     53.33       1210.0    800.0      0         Apartamento       0        1
# 3     16.67       1030.0    800.0      0         Apartamento       0        1
# 4     26.00       1618.0   1300.0      0         Apartamento       0        2
# 5     29.33      22000.0  22000.0      4  Casa de Condomínio       5        5
# 6     15.38       1000.0   1000.0      2  Casa de Condomínio       0        2
# 7     21.43       2216.0   1500.0      1         Apartamento       0        2
# 8     16.67       1969.0   1500.0      1         Apartamento       1        3
# 9     50.00       2611.0   2000.0      0         Apartamento       1        1
#
#    IPTU  Condominio               Bairro  Area
# 0  60.0       500.0           Copacabana    40
# ...

# %% [markdown]
# ### Continuando com a divisão

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados['Area']).round(2)
dados.head(10).sort_index(axis=1, ascending=False)
# Out:
#    Valor m2  Valor Bruto m2  Valor Bruto    Valor  Vagas                Tipo  \
# 0     42.50           56.50       2260.0   1700.0      0           Quitinete
# 1     70.00           70.00       7000.0   7000.0      0                Casa
# 2     53.33           80.67       1210.0    800.0      0         Apartamento
# 3     16.67           21.46       1030.0    800.0      0         Apartamento
# 4     26.00           32.36       1618.0   1300.0      0         Apartamento
# 5     29.33           29.33      22000.0  22000.0      4  Casa de Condomínio
# 6     15.38           15.38       1000.0   1000.0      2  Casa de Condomínio
# 7     21.43           31.66       2216.0   1500.0      1         Apartamento
# 8     16.67           21.88       1969.0   1500.0      1         Apartamento
# 9     50.00           65.28       2611.0   2000.0      0         Apartamento
#
#    Suites  Quartos  IPTU  Condominio               Bairro  Area
# ...

# %% [markdown]
# ## Filtrando Valores para Criar uma Nova Variável

# %% [markdown]
# ### Listando quais valores existem em Tipo

# %%
list(dados['Tipo'].unique())
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %% [markdown]
# ### Selecionando a variável desejada

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %% [markdown]
# ### Criando a nova coluna com aplicação de uma função lambda para cada registro

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' 
                                             if x in casa else 'Apartamento')
dados.head(10).sort_index(axis=1, ascending=False)
# Out:
#    Valor m2  Valor Bruto m2  Valor Bruto    Valor  Vagas Tipo Agregado  \
# 0     42.50           56.50       2260.0   1700.0      0   Apartamento
# 1     70.00           70.00       7000.0   7000.0      0          Casa
# 2     53.33           80.67       1210.0    800.0      0   Apartamento
# 3     16.67           21.46       1030.0    800.0      0   Apartamento
# 4     26.00           32.36       1618.0   1300.0      0   Apartamento
# 5     29.33           29.33      22000.0  22000.0      4          Casa
# 6     15.38           15.38       1000.0   1000.0      2          Casa
# 7     21.43           31.66       2216.0   1500.0      1   Apartamento
# 8     16.67           21.88       1969.0   1500.0      1   Apartamento
# 9     50.00           65.28       2611.0   2000.0      0   Apartamento
#
#                  Tipo  Suites  Quartos  IPTU  Condominio               Bairro  \
# 0           Quitinete       0        1  60.0       500.0           Copacabana
# ...

# %%
# Verificando se Casa de Condomínio também recebeu o tratamento certo
dados[dados['Tipo'] == 'Casa de Condomínio'].sort_index(axis=1, 
                                                        ascending=False).head(10)
# Out:
#      Valor m2  Valor Bruto m2  Valor Bruto    Valor  Vagas Tipo Agregado  \
# 5       29.33           29.33      22000.0  22000.0      4          Casa
# 6       15.38           15.38       1000.0   1000.0      2          Casa
# 12      17.39           17.39       2000.0   2000.0      1          Casa
# 16      16.09           21.88      10195.0   7500.0      3          Casa
# 42      15.62           16.62      26600.0  25000.0     10          Casa
# 58      17.86           26.43       3700.0   2500.0      3          Casa
# 166     50.42           58.84      35010.0  30000.0      2          Casa
# 168     24.34           39.36      10508.0   6500.0      4          Casa
# 183     22.00           27.00       6750.0   5500.0      2          Casa
# 207     30.00           56.41      56410.0  30000.0      4          Casa
#
#                    Tipo  Suites  Quartos     IPTU  Condominio  \
# 5    Casa de Condomínio       5        5      0.0         0.0
# ...

# %% [markdown]
# ### Aplicando a função lambda com várias condicionais

# %%
# cuidado com os parênteses
# colocar as outras condicionais dentro de parênteses do primeiro else
# e cada if também entre parênteses
dados['Tamanho'] = dados['Quartos'].apply(lambda x: 'Grande' if x > 3 
                                          else ('Médio' if (x >= 2 and x <= 3) 
                                                else 'Pequeno'))
dados.head(10).sort_index(axis=1, ascending=False)
# Out:
#    Valor m2  Valor Bruto m2  Valor Bruto    Valor  Vagas Tipo Agregado  \
# 0     42.50           56.50       2260.0   1700.0      0   Apartamento
# 1     70.00           70.00       7000.0   7000.0      0          Casa
# 2     53.33           80.67       1210.0    800.0      0   Apartamento
# 3     16.67           21.46       1030.0    800.0      0   Apartamento
# 4     26.00           32.36       1618.0   1300.0      0   Apartamento
# 5     29.33           29.33      22000.0  22000.0      4          Casa
# 6     15.38           15.38       1000.0   1000.0      2          Casa
# 7     21.43           31.66       2216.0   1500.0      1   Apartamento
# 8     16.67           21.88       1969.0   1500.0      1   Apartamento
# 9     50.00           65.28       2611.0   2000.0      0   Apartamento
#
#                  Tipo  Tamanho  Suites  Quartos  IPTU  Condominio  \
# 0           Quitinete  Pequeno       0        1  60.0       500.0
# ...

# %%
# exportando um novo arquivo para trabalhar no próximo notebook
dados.to_csv('../dados/aluguel_res_novas_variaveis.csv', sep=';', index=False)
